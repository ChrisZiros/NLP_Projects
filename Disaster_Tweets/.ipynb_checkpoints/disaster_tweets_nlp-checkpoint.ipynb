# %% [markdown]
# ## Disaster tweets classification.
#
# Dataset was sourced from kaggle - https://www.kaggle.com/competitions/nlp-getting-started
# This python script builds and trains a series of models to predict if a disaster occurred based on X (Twitter) tweets
#
# The dataset is also available on Github: https://github.com/laxmimerit/twitter-disaster-prediction-dataset/tree/master
#
# This python script is a work in progress

# %%
# Import Libraries
import re
import string
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from wordcloud import WordCloud

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn import svm

plt.style.use('ggplot')

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, SpatialDropout1D, Dropout
from tensorflow.keras.optimizers import Adam

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Read in the data

# %%
# Below is a function to read in and create dataframes for the train and test data from my local drive.
# I have kept this code in but chose to not run it.
# I am obtaining the data from github, however, in case that data becomes unavailable, the below function is available to read in from my local drive where I have saved it
def load_from_drive():
    
    # Set the location to read the files
    base_path = "C:\\Users\\User\\Documents\\Python_Repositories\\NLP_Projects\\Disaster_Tweets\\"
    training_path = base_path + "train.csv"
    test_path = base_path + "test.csv"

    # Read in the train and test datasets and save these as dataframes
    tweet = pd.read_csv(training_path)
    tweet_test = pd.read_csv(test_path)

# %%
tweet = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/twitter-disaster-prediction-dataset/refs/heads/master/train.csv')
tweet.head()
# Out:
#    id keyword location  \
# 0   1     NaN      NaN
# 1   4     NaN      NaN
# 2   5     NaN      NaN
# 3   6     NaN      NaN
# 4   7     NaN      NaN
#
#                                                                                                                                     text  \
# 0                                                                  Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# 1                                                                                                 Forest fire near La Ronge Sask. Canada
# 2  All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 3                                                                      13,000 people receive #wildfires evacuation orders in California
# 4                                               Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# Check the number of rows and columns
tweet.shape
# Out:
# (7613, 5)

# %%
# Check null values
# some observations for keyword and location are missing
tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %% [markdown]
# ## Exploratory data analysis

# %%
# Set default parameters for plots
plt.rcParams['figure.figsize'] = [8,4]
plt.rcParams['figure.dpi'] = 120

# %% [markdown]
# Target class distribution - check number of times the target was 1 (disaster) and 0 (not a disaster)

# %%
sns.countplot(data=tweet, x = 'target', hue = 'target', palette = "Set2")
plt.title('Disaster or not a disaster')
plt.xlabel('Disaster (1), not a disaster (0)')
plt.ylabel('Number of observations')
plt.show()

# %%
# Check the actual number of observations for each of the target variable
tweet['target'].value_counts()
# Out:
# target
# 0    4342
# 1    3271
# Name: count, dtype: int64

# %%
# Create a pie plot to check the proportion of observations in each target. Display as a percentage
tweet['target'].value_counts().plot.pie(autopct = '%1.f%%')
plt.show()

# %% [markdown]
# ### Number of characters in a tweet. Distribution in the number of characters

# %%
# Install pre-process package from git.
# This is available here: https://github.com/laxmimerit/preprocess_kgptalkie
# !pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git
# Out:
# Collecting git+https://github.com/laxmimerit/preprocess_kgptalkie.git
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to c:\users\user\appdata\local\temp\pip-req-build-xdxllp22
#   Resolved https://github.com/laxmimerit/preprocess_kgptalkie.git to commit 0f56a6502679f6750b7f0ffed98f590d1f0246bd
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Running command git clone --filter=blob:none --quiet https://github.com/laxmimerit/preprocess_kgptalkie.git 'C:\Users\User\AppData\Local\Temp\pip-req-build-xdxllp22'

# %%
import preprocess_kgptalkie as kgp
# Out:
# C:\Users\User\anaconda3\envs\tflowenv\lib\site-packages\torch\__init__.py:747: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ..\torch\csrc\tensor\python_tensor.cpp:433.)
#   _C._set_default_tensor_type(t)

# %% [markdown]
# Create a feature for the number of characters in the tweet

# %%
# Create a feature for character length
tweet['char_count'] = tweet['text'].apply(lambda x: len(x))

# %%
# plot the distribution of characters in each tweet
tweet0 = tweet[tweet['target']==0]
tweet1 = tweet[tweet['target']==1]
sns.histplot(tweet0['char_count'], kde=True, label = "Not a disaster")
sns.histplot(tweet1['char_count'], kde=True, label = "Disaster")
plt.title('Number of characters in each tweet')
plt.xlabel('Number of characters')
plt.ylabel('Number of tweets')
plt.legend()
plt.show()

# %%
tweet
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                                                                                                            text  \
# 0                                                                         Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# 1                                                                                                        Forest fire near La Ronge Sask. Canada
# 2         All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 3                                                                             13,000 people receive #wildfires evacuation orders in California
# 4                                                      Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
# ...                                                                                                                                         ...
# 7608                                                        Two giant cranes holding a bridge collapse into nearby homes http://t.co/STfMbbZFB5
# 7609              @aria_ahrary @TheTawniest The out of control wild fires in California even in the Northern part of the state. Very troubling.
# 7610                                                                          M1.94 [01:04 UTC]?5km S of Volcano Hawaii. http://t.co/zDtoyd8EbJ
# 7611  Police investigating after an e-bike collided with a car in Little Portugal. E-bike rider suffered serious non-life threatening injuries.
# 7612                                             The Latest: More Homes Razed by Northern California Wildfire - ABC News http://t.co/YmY4rSkQ3d
#
#       target  char_count
# 0          1          69
# 1          1          38
# 2          1         133
# 3          1          65
# 4          1          88
# ...      ...         ...
# 7608       1          83
# 7609       1         125
# 7610       1          65
# 7611       1         137
# 7612       1          94
#
# [7613 rows x 6 columns]

# %%
sns.kdeplot(tweet[tweet['target']==0]['char_count'], fill = True)
sns.kdeplot(tweet[tweet['target']==1]['char_count'], fill = True)
plt.plot()
# Out:
# []

# %% [markdown]
# ### Number of words in a tweet

# %%
# Create a feature for the number of words
tweet['word_count'] = tweet['text'].apply(lambda x:  len(x.split(" ")))

# %%
# KDE plot for the number of words in each tweet
sns.kdeplot(tweet[tweet['target']==0]['word_count'], fill = True, color = 'blue')
sns.kdeplot(tweet[tweet['target']==1]['word_count'], fill = True, color = 'green')
plt.xlabel('Number of words')
plt.plot()
# Out:
# []

# %% [markdown]
# ### Average word length for each tweet

# %%
mylist = "I love Maho scrotums"

# %%
# Create a function to compute the average length of each word in each tweet
def avg_word_length(text):

    # Split the tweet into a list
    text = word_tokenize(text)

    # initiate an expty list to store the lengths of each word in the tweet list
    count = [] 
    for i in text:
        count.append(len(i))

    # Return the average word length as the sum of all word lengths divided by the number of words for each tweet
    return sum(count)/len(count)

# %%
# Create a feature for the number of words
tweet['avg_word_length'] = tweet['text'].apply(lambda x: avg_word_length(x))

# %%
# KDE plot for the average word length of each tweet
sns.kdeplot(tweet[tweet['target']==0]['avg_word_length'], fill = True, color = 'blue')
sns.kdeplot(tweet[tweet['target']==1]['avg_word_length'], fill = True, color = 'green')
plt.xlabel('Average word length')
plt.plot()
# Out:
# []

# %% [markdown]
# ### stop words count

# %%
# Create a function to count the number of stop words
stop_words = stopwords.words('english')
def stop_words_count(text):

    # Initialise a counter for the number of stop words
    count = 0
    
    # Tokenise to split the tweets into a list
    text = word_tokenize(text)
    
    # Loop[ through all of the words in each tweet and count the number that are stop words
    for word in text:
        if word in stop_words:
            count+=1
    return count

# %%
# Create a column for the number of stop words in each tweet
tweet['stop_word_count'] = tweet['text'].apply(lambda x: stop_words_count(x))

# %%
# KDE plot for the number of stop words in each tweet
sns.kdeplot(tweet[tweet['target']==0]['stop_word_count'], fill = True, color = 'blue', label = "Not a disaster")
sns.kdeplot(tweet[tweet['target']==1]['stop_word_count'], fill = True, color = 'green', label = "Disaster")
plt.xlabel('Number of stop words')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# ## Text Pre-Processing

# %%
# Create a function to convert the tweet to lower case and replce \\, _, . with a space
def lower_case(tweet):
    results = []
    for i in tweet['text']:
        i = str(i).lower().replace('\\',' ').replace('_',' ').replace('.',' ')
        results.append(i)
    tweet['text'] = results
    return tweet

# %%
# Create a function to remove email addresses from the tweet
def remove_email(tweet):
    results = []
    for i in tweet['text']:
        i = re.sub(r'\S*@\S*\s?', "", i)
        results.append(i)
    tweet['text'] = results
    return tweet

# %%
# Create a function to remove urls from the tweet
def remove_url(tweet):
    results = []
    for i in tweet['text']:
        i = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', "", i)
        results.append(i)
    tweet['text'] = results
    return tweet

# %%
# Create a function to remove duplicate letters from the tweet
def remove_dup_char(tweet):
    results = []
    for i in tweet['text']:
        i = re.sub("([a-zA-Z])\\1{2,}", "\\1", i)
        results.append(i)
    tweet['text'] = results
    return tweet

# %%
# Create a function to remove special characters from the tweet
def remove_special(tweet):
    results = []
    for i in tweet['text']:
        # Replace anything that is not a letter, number of space with blank
        i = re.sub('[^A-Za-z0-9 ]+', '', i)
        results.append(i)
    tweet['text'] = results
    return tweet

# %%
tweet = (tweet
         .pipe(lower_case)
         .pipe(remove_email)
         .pipe(remove_url)
         .pipe(remove_dup_char)
         .pipe(remove_special)
        )

# %%
tweet.head()
# Out:
#    id keyword location  \
# 0   1     NaN      NaN
# 1   4     NaN      NaN
# 2   5     NaN      NaN
# 3   6     NaN      NaN
# 4   7     NaN      NaN
#
#                                                                                                                                   text  \
# 0                                                                 our deeds are the reason of this earthquake may allah forgive us all
# 1                                                                                               forest fire near la ronge sask  canada
# 2  all residents asked to shelter in place are being notified by officers  no other evacuation or shelter in place orders are expected
# 3                                                                      13000 people receive wildfires evacuation orders in california
# 4                                               just got sent this photo from ruby alaska as smoke from wildfires pours into a school
#
#    target  char_count  word_count  avg_word_length  stop_word_count
# 0       1          69          13         4.071429                5
# 1       1          38           7         4.000000                0
# 2       1         133          22         4.666667                9
# 3       1          65           9         6.333333                1
# 4       1          88          17         4.000000                6

# %% [markdown]
# ## Word Cloud

# %% [markdown]
# ### Most frequent words for disaster tweets

# %%
# Compute frequency of each word in the tweets
wordfreq = tweet[tweet['target']==1]['text'].str.split(expand=True).stack().value_counts()

# %%
# Convert the text from the word frequencies into a string
wordfreq_df = pd.DataFrame(wordfreq)
disaster_freq = ' '.join(wordfreq_df.index)

# %%
# Create a wordcloud
wc = WordCloud(background_color='white', colormap = 'viridis', width = 800, height = 500).generate(disaster_freq)
plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# ## Classification using TFIDF

# %%
# Create x and y variables.
text = tweet['text']
y = tweet['target']

# %%
# Instantiate TFIDF and fit and transform to the text data
tfidf = TfidfVectorizer()
X = tfidf.fit_transform(text)

# %%
X.shape
# Out:
# (7613, 20297)

# %% [markdown]
# ### Train Test Split
# Since I am reading in the data from Github, I need to perform train test split.
# On my local drive, train and test datasets are already available, however, I am not using these

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %% [markdown]
# ### ML code

# %%
# Instantiate an svm with a linear kernel. 
clf_svm = svm.SVC(kernel='linear')

# Fit the model to the train x vectors and the y labels
clf_svm.fit(X_train, y_train)

# Predict on the test data
y_pred = clf_svm.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85      1086
#            1       0.85      0.70      0.77       818
#
#     accuracy                           0.82      1904
#    macro avg       0.82      0.80      0.81      1904
# weighted avg       0.82      0.82      0.81      1904

# %%
# Display the confusion matrix
categories = [0, 1]
conf_matrix = confusion_matrix(y_test, y_pred, labels = categories)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=categories)

# Plot the confusion matrix
disp.plot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Classification with word2vec and SVM

# %%
# Download the large spacy model
#!python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl (778.8 MB)
#      ---------------------------------------- 0.0/778.8 MB ? eta -:--:--
#      ---------------------------------------- 0.5/778.8 MB 3.3 MB/s eta 0:03:55
#      ---------------------------------------- 1.3/778.8 MB 3.2 MB/s eta 0:04:04
#      ---------------------------------------- 1.8/778.8 MB 3.0 MB/s eta 0:04:15
#      ---------------------------------------- 2.6/778.8 MB 3.1 MB/s eta 0:04:12
#      ---------------------------------------- 3.1/778.8 MB 3.1 MB/s eta 0:04:08
#      ---------------------------------------- 3.9/778.8 MB 3.1 MB/s eta 0:04:08
#      ---------------------------------------- 4.7/778.8 MB 3.2 MB/s eta 0:04:05
#      ---------------------------------------- 5.2/778.8 MB 3.2 MB/s eta 0:04:06
#      ---------------------------------------- 6.6/778.8 MB 3.4 MB/s eta 0:03:47
#      ---------------------------------------- 7.6/778.8 MB 3.6 MB/s eta 0:03:34
#      ---------------------------------------- 8.9/778.8 MB 3.9 MB/s eta 0:03:19
#       -------------------------------------- 10.2/778.8 MB 4.0 MB/s eta 0:03:11
#       -------------------------------------- 10.5/778.8 MB 4.1 MB/s eta 0:03:10
#       -------------------------------------- 11.5/778.8 MB 3.9 MB/s eta 0:03:16
#       -------------------------------------- 12.8/778.8 MB 4.0 MB/s eta 0:03:11
#       -------------------------------------- 13.9/778.8 MB 4.1 MB/s eta 0:03:07
#       -------------------------------------- 15.2/778.8 MB 4.2 MB/s eta 0:03:02
#       -------------------------------------- 15.7/778.8 MB 4.2 MB/s eta 0:03:02
#       -------------------------------------- 16.3/778.8 MB 4.1 MB/s eta 0:03:08
#       -------------------------------------- 17.3/778.8 MB 4.1 MB/s eta 0:03:06
#       -------------------------------------- 18.6/778.8 MB 4.2 MB/s eta 0:03:03
#       -------------------------------------- 19.7/778.8 MB 4.2 MB/s eta 0:03:01
#      - ------------------------------------- 20.7/778.8 MB 4.2 MB/s eta 0:02:59
#      - ------------------------------------- 21.2/778.8 MB 4.2 MB/s eta 0:03:02
#      - ------------------------------------- 22.3/778.8 MB 4.2 MB/s eta 0:03:00
#      - ------------------------------------- 23.1/778.8 MB 4.2 MB/s eta 0:03:01
#      - ------------------------------------- 23.9/778.8 MB 4.1 MB/s eta 0:03:02
#      - ------------------------------------- 24.9/778.8 MB 4.2 MB/s eta 0:03:01
#      - ------------------------------------- 26.0/778.8 MB 4.2 MB/s eta 0:03:00
#      - ------------------------------------- 27.0/778.8 MB 4.2 MB/s eta 0:02:58
#      - ------------------------------------- 28.0/778.8 MB 4.3 MB/s eta 0:02:57
#      - ------------------------------------- 29.1/778.8 MB 4.3 MB/s eta 0:02:55
#      - ------------------------------------- 30.4/778.8 MB 4.3 MB/s eta 0:02:54
#      - ------------------------------------- 31.5/778.8 MB 4.3 MB/s eta 0:02:53
#      ------------------------------------ - 737.9/778.8 MB 4.4 MB/s eta 0:00:10
#      ------------------------------------ - 739.0/778.8 MB 4.4 MB/s eta 0:00:10
#      ------------------------------------ - 740.0/778.8 MB 4.4 MB/s eta 0:00:09
#      ------------------------------------ - 741.3/778.8 MB 4.4 MB/s eta 0:00:09
#      ------------------------------------ - 742.1/778.8 MB 4.5 MB/s eta 0:00:09
#      ------------------------------------ - 742.9/778.8 MB 4.5 MB/s eta 0:00:09
#      ------------------------------------ - 744.0/778.8 MB 4.5 MB/s eta 0:00:08
#      ------------------------------------ - 745.0/778.8 MB 4.5 MB/s eta 0:00:08
#      ------------------------------------ - 746.1/778.8 MB 4.4 MB/s eta 0:00:08
#      ------------------------------------ - 747.1/778.8 MB 4.4 MB/s eta 0:00:08
#      ------------------------------------ - 747.9/778.8 MB 4.4 MB/s eta 0:00:07
#      ------------------------------------ - 748.9/778.8 MB 4.4 MB/s eta 0:00:07
#      ------------------------------------ - 750.0/778.8 MB 4.5 MB/s eta 0:00:07
#      ------------------------------------ - 751.0/778.8 MB 4.5 MB/s eta 0:00:07
#      ------------------------------------ - 751.8/778.8 MB 4.4 MB/s eta 0:00:07
#      ------------------------------------ - 752.6/778.8 MB 4.4 MB/s eta 0:00:06
#      ------------------------------------ - 753.7/778.8 MB 4.4 MB/s eta 0:00:06
#      ------------------------------------ - 754.7/778.8 MB 4.4 MB/s eta 0:00:06
#      ------------------------------------ - 755.8/778.8 MB 4.4 MB/s eta 0:00:06
#      ------------------------------------ - 757.1/778.8 MB 4.4 MB/s eta 0:00:05
#      -------------------------------------  758.4/778.8 MB 4.4 MB/s eta 0:00:05
#      -------------------------------------  759.7/778.8 MB 4.5 MB/s eta 0:00:05
#      -------------------------------------  761.0/778.8 MB 4.5 MB/s eta 0:00:04
#      -------------------------------------  762.3/778.8 MB 4.5 MB/s eta 0:00:04
#      -------------------------------------  763.6/778.8 MB 4.5 MB/s eta 0:00:04
#      -------------------------------------  764.7/778.8 MB 4.5 MB/s eta 0:00:04
#      -------------------------------------  766.2/778.8 MB 4.5 MB/s eta 0:00:03
#      -------------------------------------  767.6/778.8 MB 4.5 MB/s eta 0:00:03
#      -------------------------------------  768.9/778.8 MB 4.5 MB/s eta 0:00:03
#      -------------------------------------  769.9/778.8 MB 4.5 MB/s eta 0:00:02
#      -------------------------------------  770.4/778.8 MB 4.5 MB/s eta 0:00:02
#      -------------------------------------  771.0/778.8 MB 4.5 MB/s eta 0:00:02
#      -------------------------------------  772.0/778.8 MB 4.5 MB/s eta 0:00:02
#      -------------------------------------  773.1/778.8 MB 4.5 MB/s eta 0:00:02
#      -------------------------------------  773.8/778.8 MB 4.5 MB/s eta 0:00:02
#      -------------------------------------  774.9/778.8 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  775.7/778.8 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  776.5/778.8 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  777.8/778.8 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  778.6/778.8 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  778.6/778.8 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  778.6/778.8 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  778.6/778.8 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  778.6/778.8 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  778.6/778.8 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  778.6/778.8 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------- 778.8/778.8 MB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from en-core-web-lg==3.0.0) (3.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.10)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.10)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (4.67.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.8.2)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (75.8.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (24.2)
# Requirement already satisfied: pathlib-abc==0.1.1 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2025.4.26)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.4.6)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\tflowenv\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.2)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.0.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# DEPRECATION: https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl#egg=en_core_web_lg==3.0.0 contains an egg fragment with a non-PEP 508 name. pip 25.1 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/13157

# %%
import spacy
import en_core_web_lg

# %%
# Instantiate the model
nlp = spacy.load("en_core_web_lg")

# %%
# Create word vector representations for each tweet
def get_vec(x):
    doc = nlp(x)
    vec = doc.vector
    return vec

# %%
tweet['vec'] = tweet['text'].apply(lambda x: get_vec(x))

# %%
# Convert the vectorised text to a numpy array and reshape
X = tweet['vec'].to_numpy()
X = X.reshape(-1,1)

# %%
X = np.concatenate(np.concatenate(X, axis=0), axis=0).reshape(-1,300)

# %%
X.shape
# Out:
# (7613, 300)

# %%
# y variable as the target
y = tweet['target']

# %% [markdown]
# ### Train Test Split
